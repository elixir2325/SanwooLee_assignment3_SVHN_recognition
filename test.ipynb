# %%
import mat73
matfile = mat73.loadmat('data/train/digitStruct.mat')

# %%
matfile_test = mat73.loadmat('data/test/digitStruct.mat')

# %%
import pickle

with open('data/train/digit_struct.pickle', 'wb') as handle:
    pickle.dump(matfile, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle

with open('data/test/digit_struct.pickle', 'wb') as handle:
    pickle.dump(matfile_test, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle
with  open('data/train/digit_struct.pickle', 'rb') as handle:
    b = pickle.load(handle)

# %%
b['digitStruct']['bbox'][24], b['digitStruct']['name'][24]
# Out:
# ({'height': [array(50.), array(50.), array(50.)],
#   'label': [array(6.), array(10.), array(1.)],
#   'left': [array(60.), array(87.), array(113.)],
#   'top': [array(11.), array(9.), array(7.)],
#   'width': [array(24.), array(24.), array(21.)]},
#  '25.png')

# %%
matfile['digitStruct']['bbox'][1]
# Out:
# {'height': [array(32.), array(32.)],
#  'label': [array(2.), array(3.)],
#  'left': [array(77.), array(98.)],
#  'top': [array(29.), array(25.)],
#  'width': [array(23.), array(26.)]}

# %%
from PIL import Image
from torchvision.io import read_image
import cv2
import matplotlib.pyplot as plt

# img = read_image('data/train/1.png')
im = cv2.imread('data/train/1.png')

# %%
type(im)
# Out:
# numpy.ndarray

# %%
im.shape
# Out:
# (350, 741, 3)

# %%
plt.imshow(im)

# %%
# Out:
# torch.Size([3, 350, 741])

# %%
import torch
import torch.nn as nn

a = nn.Sequential( nn.Linear(2,1), nn.ReLU())
b = nn.Sequential( nn.Linear(3,1), nn.ReLU())

# %%
a+b
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=1, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=3, out_features=1, bias=True)
#   (3): ReLU()
# )

# %%
a = torch.rand(16,48, 64, 64)
a
# Out:
# tensor([[[[4.3084e-01, 1.7945e-01, 9.4430e-01,  ..., 2.6675e-01,
#            2.7736e-01, 5.5092e-01],
#           [1.7035e-01, 2.5990e-01, 6.0818e-01,  ..., 7.8727e-01,
#            1.3072e-01, 4.0255e-01],
#           [9.6458e-01, 2.7419e-01, 4.4639e-02,  ..., 9.0732e-01,
#            2.9063e-01, 9.3624e-01],
#           ...,
#           [1.0262e-01, 2.1109e-01, 4.2730e-02,  ..., 6.3868e-01,
#            6.8666e-01, 1.3654e-01],
#           [2.4442e-01, 2.5641e-01, 8.2783e-01,  ..., 6.4252e-01,
#            5.1916e-01, 2.5198e-01],
#           [6.7397e-01, 1.3892e-01, 8.4493e-01,  ..., 1.5457e-01,
#            1.0058e-01, 4.8752e-01]],
#
#          [[7.1084e-01, 5.3964e-01, 7.3255e-01,  ..., 3.3407e-01,
#            2.2400e-01, 3.5184e-02],
#           [3.1444e-01, 9.6211e-01, 2.9585e-02,  ..., 6.9810e-01,
#            7.3200e-01, 7.9070e-01],
#           [2.0013e-02, 1.9287e-01, 2.3219e-01,  ..., 7.3406e-01,
#            6.7594e-01, 5.3892e-01],
#           ...,
# ...

# %%
pool = torch.nn.MaxPool2d(2, 2, padding=1)
pool(a).shape
# Out:
# torch.Size([16, 48, 33, 33])

# %%
from torchvision.datasets import SVHN
from torchvision import transforms

# %%
svhn_dataset = SVHN(root="<root_path>", split='test', download=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27116\3654641616.py in <module>
# ----> 1 svhn_dataset = SVHN( split='test', download=True)
#
# TypeError: __init__() missing 1 required positional argument: 'root'
